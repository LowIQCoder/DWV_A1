# %% [markdown]
# # Important
#
# Since I can not add any text to my moodle submission, I provide all links
#
# GitHub link: https://github.com/LowIQCoder/DWV_A1
#
# Deployed page: https://lowiqcoder.github.io/DWV_A1/

# %% [markdown]
# # Backend part of Assigment I
#
# Here you can find source code of scrapper, analisys, and work with database

# %% [markdown]
# ## Scraper
#
# First of all we need to obtain data. We will use **High-grossing films by year of release** table, since it contains the most number of films.

# %% [markdown]
# For parsing we will use **beautifull soup** and **Requests** libraries. It will provide all needed features and also it less complicated then **Scrapy**.

# %%
# Libraries for parcing
import requests
from bs4 import BeautifulSoup
import csv
import re

# Libraries for analisys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Libraties for DB interaction
import psycopg2
import os
from dotenv import load_dotenv

# Other
import csv
import json

# %% [markdown]
# Information for each film contains in *infobox* table. To parce all data the following function will be used

# %%
def parse_infobox(url):
    """
    Parses the "infobox vevent" table from a Wikipedia page and extracts relevant movie details.
    :param url: Wikipedia page URL
    :return: Dictionary with extracted data
    """
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the infobox table
    infobox = soup.find("table", class_="infobox vevent")
    if not infobox:
        print("Infobox not found!")
        return None
    
    data = {
        'year': None,
        'title': None,
        'director': None,
        'distributor': None,
        'country': None,
        'running_time': None,
        'budget': None,
        'box_office': None
    }
    
    # Function to clean text (removes references and extra spaces)
    def clean_text(text):
        text = re.sub(r'\[.*?\]', '', text)  # Remove references (e.g., [1], [2])
        text = text.replace('\n', ' ').strip()  # Remove new lines and extra spaces
        return text
    
    # Extract directed by
    row = infobox.find("th", string="Directed by")
    if row:
        data['director'] = clean_text(row.find_next("td").text).replace("–", " ")
    
    # Extract distributor
    row = infobox.find("th", string="Distributed by")
    if row:
        data['distributor'] = clean_text(row.find_next("td").text)
    
    # Extract country (first country if multiple present in ul element)
    row = infobox.find("th", string=re.compile("Country|Countries"))
    if row:
        country_td = row.find_next("td")
        if country_td.find("ul"):
            first_country = country_td.find("ul").find("li")
            if first_country:
                data['country'] = clean_text(first_country.text)
        else:
            data['country'] = clean_text(country_td.text.split(',')[0])
    
    # Extract running time (only integer part in minutes)
    row = infobox.find("th", string="Running time")
    if row:
        time_text = clean_text(row.find_next("td").text)
        time_match = re.search(r'(\d+)\s*minutes', time_text)
        if time_match:
            data['running_time'] = int(time_match.group(1))
        else:
            data['running_time'] = None
    
    # Extract budget (convert to millions)
    row = infobox.find("th", string="Budget")
    if row:
        data['budget'] = row.find_next("td").text
        value = re.search(r"\$[\d,.]*", data['budget']).group()[1:].replace(',', '')
        if re.search(r"(million)", data['budget']):
            value = int(float(value) * 1e6)
        data['budget'] = value
        

    # Extract box office revenue (convert to millions)
    row = infobox.find("th", string="Box office")
    if row:
        data['box_office'] = row.find_next("td").text
        value = re.search(r"\$[\d,.]*", data['box_office']).group()[1:].replace(',', '')
        if re.search(r"(million)", data['box_office']):
            value = int(float(value) * 1e6)
        elif re.search(r"(billion)", data['box_office']):
            value = int(float(value) * 1e9)
        data['box_office'] = value

    
    return data

# %% [markdown]
# Test our parce_infobox function. Note that 'year' and 'title' will be parced later, so it is fine if now there are None values

# %%
parse_infobox("https://en.wikipedia.org/wiki/You_Can%27t_Take_It_with_You_(film)")
# Out:
# {'year': None,
#  'title': None,
#  'director': 'Frank Capra',
#  'distributor': 'Columbia Pictures',
#  'country': 'United States',
#  'running_time': 126,
#  'budget': '1644736',
#  'box_office': '2137575'}

# %% [markdown]
# Now define function that will parce our table. It iterates througth each row and extracts 'year', 'title', and 'url'. Url field is used to access dedicated films wiki page.

# %%
def parse_high_grossing_films(url):
    """
    Parses the second 'High-grossing films by year of release' table from a Wikipedia page,
    extracts the year and film href, and uses that data to call parse_infobox.
    Saves the collected data into a CSV file.
    :param url: Wikipedia page URL with the high-grossing films table
    """
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    tables = soup.find_all("table", class_="wikitable plainrowheaders")
    
    table = tables[1]
    rows = table.find_all("tr")[1:]

    films = []

    for row in rows[:len(rows)-1]:
        if row.find("th") is None:
            continue
        href = row.find("td").find("a").attrs["href"]
        film_data = parse_infobox("https://en.wikipedia.org" + href)
        film_data["year"] = row.find("th").find("a").text
        film_data["title"] = row.find("td").find("a").text
        film_data["url"] = "https://en.wikipedia.org" + href
        print(film_data)
        films.append(film_data)

    return films

# %% [markdown]
# Allso, add function for saving our data to csv

# %%
def save_to_csv(film_data, filename="output/high_grossing_films.csv"):
    """
    Saves the extracted film data to a CSV file.
    :param film_data: List of dictionaries containing film details
    :param filename: Name of the output CSV file
    """
    with open(filename, "w", newline="") as file:
        fieldnames = ["year", "title", "director", "distributor", "country", "running_time", "budget", "box_office", "url"]
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()
        for data in film_data:
            writer.writerow(data)
    
    print(f"Data saved to {filename}")

# %% [markdown]
# Now we can start our parcer. Note that sometimes that action will take long time, due to slow internet connection (or current moon phase :) )

# %%
url = "https://en.wikipedia.org/wiki/List_of_highest-grossing_films"
data = parse_high_grossing_films(url)
# Out:
# {'year': '1915', 'title': 'The Birth of a Nation', 'director': 'D. W. Griffith', 'distributor': 'Epoch Producing Co.', 'country': 'United States', 'running_time': 193, 'budget': '100000', 'box_office': 50000000, 'url': 'https://en.wikipedia.org/wiki/The_Birth_of_a_Nation'}
# {'year': '1916', 'title': 'Intolerance', 'director': 'D. W. Griffith', 'distributor': 'Triangle Distributing Corporation', 'country': 'United States', 'running_time': 210, 'budget': '385907', 'box_office': 1750000, 'url': 'https://en.wikipedia.org/wiki/Intolerance_(film)'}
# {'year': '1917', 'title': 'Cleopatra', 'director': 'J. Gordon Edwards', 'distributor': 'Fox Film Corporation', 'country': 'United States', 'running_time': None, 'budget': '250000', 'box_office': 1000000, 'url': 'https://en.wikipedia.org/wiki/Cleopatra_(1917_film)'}
# {'year': '1918', 'title': 'Mickey', 'director': 'F. Richard JonesJames Young', 'distributor': 'States Rights Independent ExchangesFilm Booking Offices of America (FBO)', 'country': 'United States', 'running_time': 93, 'budget': '250000', 'box_office': '16450000', 'url': 'https://en.wikipedia.org/wiki/Mickey_(1918_film)'}
# {'year': '1976', 'title': 'Rocky', 'director': 'John G. Avildsen', 'distributor': 'United Artists (USA)Star Cinema (Philippines)', 'country': 'United States', 'running_time': 119, 'budget': '1100000', 'box_office': 225000000, 'url': 'https://en.wikipedia.org/wiki/Rocky'}
# {'year': '1977', 'title': 'Star Wars', 'director': 'George Lucas', 'distributor': 'Twentieth Century-Fox', 'country': 'United States', 'running_time': 121, 'budget': 11000000, 'box_office': 775400000, 'url': 'https://en.wikipedia.org/wiki/Star_Wars_(film)'}
# {'year': '1978', 'title': 'Grease', 'director': 'Randal Kleiser', 'distributor': 'Paramount Pictures', 'country': 'United States', 'running_time': 110, 'budget': 6000000, 'box_office': 396300000, 'url': 'https://en.wikipedia.org/wiki/Grease_(film)'}
# {'year': '1979', 'title': 'Moonraker', 'director': 'Lewis Gilbert', 'distributor': 'United Artists', 'country': 'United KingdomUnited StatesFrance', 'running_time': 126, 'budget': 34000000, 'box_office': 210300000, 'url': 'https://en.wikipedia.org/wiki/Moonraker_(film)'}
# {'year': '1980', 'title': 'The Empire Strikes Back', 'director': 'Irvin Kershner', 'distributor': '20th Century-Fox', 'country': 'United States', 'running_time': 124, 'budget': 30500000, 'box_office': 538000000, 'url': 'https://en.wikipedia.org/wiki/The_Empire_Strikes_Back'}
# {'year': '1981', 'title': 'Raiders of the Lost Ark', 'director': 'Steven Spielberg', 'distributor': 'Paramount Pictures', 'country': 'United States', 'running_time': 115, 'budget': 20000000, 'box_office': 389900000, 'url': 'https://en.wikipedia.org/wiki/Raiders_of_the_Lost_Ark'}
# {'year': '1982', 'title': 'E.T. the Extra-Terrestrial', 'director': 'Steven Spielberg', 'distributor': 'Universal Pictures', 'country': 'United States', 'running_time': 114, 'budget': 10500000, 'box_office': 797300000, 'url': 'https://en.wikipedia.org/wiki/E.T._the_Extra-Terrestrial'}
# {'year': '1983', 'title': 'Return of the Jedi', 'director': 'Richard Marquand', 'distributor': '20th Century-Fox', 'country': 'United States', 'running_time': 132, 'budget': 32500000, 'box_office': 482000000, 'url': 'https://en.wikipedia.org/wiki/Return_of_the_Jedi'}
# {'year': '1984', 'title': 'Ghostbusters', 'director': 'Ivan Reitman', 'distributor': 'Columbia Pictures', 'country': 'United States', 'running_time': 105, 'budget': 25000000, 'box_office': 370000000, 'url': 'https://en.wikipedia.org/wiki/Ghostbusters'}
# {'year': '1985', 'title': 'Back to the Future', 'director': 'Robert Zemeckis', 'distributor': 'Universal Pictures', 'country': 'United States', 'running_time': 116, 'budget': 19000000, 'box_office': 388800000, 'url': 'https://en.wikipedia.org/wiki/Back_to_the_Future'}
# {'year': '1986', 'title': 'Top Gun', 'director': 'Tony Scott', 'distributor': 'Paramount Pictures', 'country': 'United States', 'running_time': 109, 'budget': 15000000, 'box_office': 357300000, 'url': 'https://en.wikipedia.org/wiki/Top_Gun'}
# {'year': '1987', 'title': 'Fatal Attraction', 'director': 'Adrian Lyne', 'distributor': 'Paramount Pictures', 'country': 'United States', 'running_time': 119, 'budget': 14000000, 'box_office': 320100000, 'url': 'https://en.wikipedia.org/wiki/Fatal_Attraction'}
# {'year': '1988', 'title': 'Rain Man', 'director': 'Barry Levinson', 'distributor': 'MGM/UA Communications Co.', 'country': 'United States', 'running_time': 134, 'budget': 25000000, 'box_office': 354800000, 'url': 'https://en.wikipedia.org/wiki/Rain_Man'}
# {'year': '1989', 'title': 'Indiana Jones and the Last Crusade', 'director': 'Steven Spielberg', 'distributor': 'Paramount Pictures', 'country': 'United States', 'running_time': 128, 'budget': 48000000, 'box_office': 474200000, 'url': 'https://en.wikipedia.org/wiki/Indiana_Jones_and_the_Last_Crusade'}
# {'year': '1990', 'title': 'Ghost', 'director': 'Jerry Zucker', 'distributor': 'Paramount Pictures', 'country': 'United States', 'running_time': 127, 'budget': 22000000, 'box_office': 505700000, 'url': 'https://en.wikipedia.org/wiki/Ghost_(1990_film)'}
# {'year': '1991', 'title': 'Terminator 2: Judgment Day', 'director': 'James Cameron', 'distributor': 'Tri-Star Pictures', 'country': 'United States', 'running_time': 137, 'budget': 94000000, 'box_office': 519000000, 'url': 'https://en.wikipedia.org/wiki/Terminator_2:_Judgment_Day'}
# {'year': '1992', 'title': 'Aladdin', 'director': 'John Musker Ron Clements', 'distributor': 'Buena Vista Pictures Distribution', 'country': 'United States', 'running_time': 90, 'budget': 28000000, 'box_office': 504100000, 'url': 'https://en.wikipedia.org/wiki/Aladdin_(1992_Disney_film)'}
# {'year': '1993', 'title': 'Jurassic Park', 'director': 'Steven Spielberg', 'distributor': 'Universal Pictures', 'country': 'United States', 'running_time': 127, 'budget': 63000000, 'box_office': 1058000000, 'url': 'https://en.wikipedia.org/wiki/Jurassic_Park_(film)'}
# {'year': '1994', 'title': 'The Lion King', 'director': 'Roger Allers Rob Minkoff', 'distributor': 'Buena Vista Pictures Distribution', 'country': 'United States', 'running_time': 88, 'budget': 45000000, 'box_office': 978800000, 'url': 'https://en.wikipedia.org/wiki/The_Lion_King'}
# {'year': '1995', 'title': 'Toy Story', 'director': 'John Lasseter', 'distributor': 'Buena Vista Pictures Distribution', 'country': 'United States', 'running_time': 81, 'budget': 30000000, 'box_office': 394400000, 'url': 'https://en.wikipedia.org/wiki/Toy_Story'}
# {'year': '1996', 'title': 'Independence Day', 'director': 'Roland Emmerich', 'distributor': '20th Century Fox', 'country': 'United States', 'running_time': 145, 'budget': 75000000, 'box_office': 817400000, 'url': 'https://en.wikipedia.org/wiki/Independence_Day_(1996_film)'}
# {'year': '1997', 'title': 'Titanic', 'director': 'James Cameron', 'distributor': 'Paramount Pictures 20th Century Fox', 'country': 'United States', 'running_time': 195, 'budget': 200000000, 'box_office': 2264000000, 'url': 'https://en.wikipedia.org/wiki/Titanic_(1997_film)'}
# {'year': '1998', 'title': 'Armageddon', 'director': 'Michael Bay', 'distributor': 'Buena Vista Pictures Distribution', 'country': 'United States', 'running_time': 150, 'budget': 140000000, 'box_office': 553700000, 'url': 'https://en.wikipedia.org/wiki/Armageddon_(1998_film)'}
# {'year': '1999', 'title': 'Star Wars: Episode I – The Phantom Menace', 'director': 'George Lucas', 'distributor': '20th Century Fox', 'country': 'United States', 'running_time': 134, 'budget': 115000000, 'box_office': 1046999999, 'url': 'https://en.wikipedia.org/wiki/Star_Wars:_Episode_I_%E2%80%93_The_Phantom_Menace'}
# {'year': '2000', 'title': 'Mission: Impossible 2', 'director': 'John Woo', 'distributor': 'Paramount Pictures', 'country': 'United States', 'running_time': 124, 'budget': 120000000, 'box_office': 546300000, 'url': 'https://en.wikipedia.org/wiki/Mission:_Impossible_2'}
# {'year': '2001', 'title': "Harry Potter and the Philosopher's Stone", 'director': 'Chris Columbus', 'distributor': 'Warner Bros. Pictures', 'country': 'United Kingdom', 'running_time': 152, 'budget': 125000000, 'box_office': 1026000000, 'url': 'https://en.wikipedia.org/wiki/Harry_Potter_and_the_Philosopher%27s_Stone_(film)'}
# {'year': '2002', 'title': 'The Lord of the Rings: The Two Towers', 'director': 'Peter Jackson', 'distributor': 'New Line Cinema', 'country': 'New Zealand', 'running_time': 179, 'budget': 94000000, 'box_office': 951600000, 'url': 'https://en.wikipedia.org/wiki/The_Lord_of_the_Rings:_The_Two_Towers'}
# {'year': '2003', 'title': 'The Lord of the Rings: The Return of the King', 'director': 'Peter Jackson', 'distributor': 'New Line Cinema', 'country': 'New Zealand', 'running_time': 201, 'budget': 94000000, 'box_office': 1151000000, 'url': 'https://en.wikipedia.org/wiki/The_Lord_of_the_Rings:_The_Return_of_the_King'}
# {'year': '2004', 'title': 'Shrek 2', 'director': 'Andrew Adamson Kelly Asbury Conrad Vernon', 'distributor': 'DreamWorks Pictures (through DreamWorks Distribution)', 'country': 'United States', 'running_time': 92, 'budget': 150000000, 'box_office': 935500000, 'url': 'https://en.wikipedia.org/wiki/Shrek_2'}
# {'year': '2005', 'title': 'Harry Potter and the Goblet of Fire', 'director': 'Mike Newell', 'distributor': 'Warner Bros. Pictures', 'country': 'United Kingdom', 'running_time': 157, 'budget': 150000000, 'box_office': 897500000, 'url': 'https://en.wikipedia.org/wiki/Harry_Potter_and_the_Goblet_of_Fire_(film)'}
# {'year': '2006', 'title': "Pirates of the Caribbean: Dead Man's Chest", 'director': 'Gore Verbinski', 'distributor': 'Buena Vista Pictures Distribution', 'country': 'United States', 'running_time': 151, 'budget': 225000000, 'box_office': 1066000000, 'url': 'https://en.wikipedia.org/wiki/Pirates_of_the_Caribbean:_Dead_Man%27s_Chest'}
# {'year': '2007', 'title': "Pirates of the Caribbean: At World's End", 'director': 'Gore Verbinski', 'distributor': 'Buena Vista Pictures Distribution', 'country': 'United States', 'running_time': 168, 'budget': 300000000, 'box_office': 963400000, 'url': 'https://en.wikipedia.org/wiki/Pirates_of_the_Caribbean:_At_World%27s_End'}
# {'year': '2008', 'title': 'The Dark Knight', 'director': 'Christopher Nolan', 'distributor': 'Warner Bros. Pictures', 'country': 'United States', 'running_time': 152, 'budget': 185000000, 'box_office': 1006000000, 'url': 'https://en.wikipedia.org/wiki/The_Dark_Knight'}
# {'year': '2009', 'title': 'Avatar', 'director': 'James Cameron', 'distributor': '20th Century Fox', 'country': 'United Kingdom', 'running_time': 162, 'budget': 237000000, 'box_office': 2923000000, 'url': 'https://en.wikipedia.org/wiki/Avatar_(2009_film)'}
# {'year': '2010', 'title': 'Toy Story 3', 'director': 'Lee Unkrich', 'distributor': 'Walt Disney StudiosMotion Pictures', 'country': 'United States', 'running_time': 103, 'budget': 200000000, 'box_office': 1067000000, 'url': 'https://en.wikipedia.org/wiki/Toy_Story_3'}
# {'year': '2011', 'title': 'Harry Potter and the Deathly Hallows – Part 2', 'director': 'David Yates', 'distributor': 'Warner Bros. Pictures', 'country': 'United Kingdom', 'running_time': 130, 'budget': 250000000, 'box_office': 1342000000, 'url': 'https://en.wikipedia.org/wiki/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_
# {'year': '2023', 'title': 'Barbie', 'director': 'Greta Gerwig', 'distributor': 'Warner Bros. Pictures', 'country': 'United States', 'running_time': 114, 'budget': 128000000, 'box_office': 1446000000, 'url': 'https://en.wikipedia.org/wiki/Barbie_(film)'}
# {'year': '2024', 'title': 'Inside Out 2', 'director': 'Kelsey Mann', 'distributor': 'Walt Disney StudiosMotion Pictures', 'country': 'United States', 'running_time': 96, 'budget': 200000000, 'box_office': 1699000000, 'url': 'https://en.wikipedia.org/wiki/Inside_Out_2'}

# %% [markdown]
# Now we just save all obtained data

# %%
save_to_csv(data)
# Out:
# Data saved to output/high_grossing_films.csv

# %% [markdown]
# ## Data analisys
#
# Ofcourse I will analise obtained data. **Pandas** dataframe will be used to store all data. Additionaly to plot graphs **Matplotlib** will be used.

# %% [markdown]
# Read our data

# %%
df = pd.read_csv('output/high_grossing_films.csv', encoding='cp1252')

# %% [markdown]
# Now we can look at our data little closer

# %%
years = np.array(df["year"].iloc[:])

fig, ax = plt.subplots(2, 2)
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
# Film budget by year
ax[0][0].set_title("Films budget by year")
ax[0][0].plot(years, np.array(df["budget"].iloc[:]))

# Box office by year
ax[0][1].set_title("Box office by year")
ax[0][1].plot(years, np.array(df["box_office"].iloc[:]))

# Revenue by year
ax[1][0].set_title("Revenue by year")
ax[1][0].plot(years, np.array(df["box_office"].iloc[:]) - np.array(df["budget"].iloc[:]))

# Most populae distributors
distributors = df["distributor"].unique()
ranks = {}
for distributor in distributors:
    ranks[distributor] = df[df["distributor"] == distributor]["distributor"].count()
ax[1][1].set_title("Most popular distributors")
ax[1][1].hist(ranks.values(), bins=len(distributors))

# Some stats
print("The most expensive")
for film in df.nlargest(5, ["budget"]).iloc[:].values:
    print(film[1], film[6])
print("\nHighest box office")
for film in df.nlargest(5, ["box_office"]).iloc[:].values:
    print(film[1], film[6])
# Out:
# The most expensive
# The Four Horsemen of the Apocalypse 800000000000.0
# Star Wars: The Force Awakens 447000000.0
# Avengers: Endgame 356000000.0
# Avatar: The Way of Water 350000000.0
# Avengers: Infinity War 325000000.0
#
# Highest box office
# Avatar 237000000.0
# Avengers: Endgame 356000000.0
# Avatar: The Way of Water 350000000.0
# Titanic 200000000.0
# Star Wars: The Force Awakens 447000000.0

# %% [markdown]
# Something is strange... Over here we have 1 misstake:
#
# 1921,The Four Horsemen of the Apocalypse,Rex Ingram,Metro Pictures,United States,134,800000000000,9200000,https://en.wikipedia.org/wiki/The_Four_Horsemen_of_the_Apocalypse_(film)
#
# Here film cost is overestimated. What is why we need to analyse data.
#
# After manualy fixing data we have the following:

# %%
df.loc[6, 'budget'] = 800_000
df[df['year'] == 1921]
# Out:
#    year                                title    director     distributor  \
# 6  1921  The Four Horsemen of the Apocalypse  Rex Ingram  Metro Pictures
#
#          country  running_time    budget  box_office  \
# 6  United States         134.0  800000.0     9200000
#
#                                                  url
# 6  https://en.wikipedia.org/wiki/The_Four_Horseme...

# %%
df.describe()
# Out:
#               year  running_time        budget    box_office
# count   110.000000    108.000000  1.080000e+02  1.100000e+02
# mean   1969.500000    132.314815  6.155056e+07  5.034441e+08
# std      31.898276     37.538428  9.870896e+07  6.467323e+08
# min    1915.000000     60.000000  6.700100e+04  1.000000e+06
# 25%    1942.250000    104.750000  1.775000e+06  1.875000e+07
# 50%    1969.500000    127.000000  1.075000e+07  2.587000e+08
# 75%    1996.750000    152.000000  9.400000e+07  8.123750e+08
# max    2024.000000    243.000000  4.470000e+08  2.923000e+09

# %%
df[df["running_time"].isnull()]
# Out:
#    year            title             director           distributor  \
# 2  1917        Cleopatra    J. Gordon Edwards  Fox Film Corporation
# 4  1919  The Miracle Man  George Loane Tucker  Famous Players–Lasky
#
#          country  running_time    budget  box_office  \
# 2  United States           NaN  250000.0     1000000
# 4  United States           NaN  120000.0     1000000
#
#                                                  url
# 2  https://en.wikipedia.org/wiki/Cleopatra_(1917_...
# 4  https://en.wikipedia.org/wiki/The_Miracle_Man_...

# %%
df[df["budget"].isnull()]
# Out:
#     year              title     director         distributor        country  \
# 11  1926  For Heaven's Sake   Sam Taylor  Paramount Pictures  United States
# 29  1944       Going My Way  Leo McCarey  Paramount Pictures  United States
#
#     running_time  budget  box_office  \
# 11          60.0     NaN     2600000
# 29         126.0     NaN     6500000
#
#                                                   url
# 11  https://en.wikipedia.org/wiki/For_Heaven%27s_S...
# 29         https://en.wikipedia.org/wiki/Going_My_Way

# %%
df[df["box_office"].isnull()]
# Out:
# Empty DataFrame
# Columns: [year, title, director, distributor, country, running_time, budget, box_office, url]
# Index: []

# %%
# Since it only 4 null values, we can update them manualy
df.loc[2, 'running_time'] = 125
df.loc[4, 'running_time'] = 160
df.loc[11, 'budget'] = 2000000
df.loc[29, 'budget'] = 3000000

# %%
years = np.array(df["year"].iloc[:])

fig, ax = plt.subplots(2, 2)
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
# Film budget by year
ax[0][0].set_title("Films budget by year")
ax[0][0].plot(years, np.array(df["budget"].iloc[:]))

# Box office by year
ax[0][1].set_title("Box office by year")
ax[0][1].plot(years, np.array(df["box_office"].iloc[:]))

# Revenue by year
ax[1][0].set_title("Revenue by year")
ax[1][0].plot(years, np.array(df["box_office"].iloc[:]) - np.array(df["budget"].iloc[:]))

# Most populae distributors
distributors = df["distributor"].unique()
ranks = {}
for distributor in distributors:
    ranks[distributor] = df[df["distributor"] == distributor]["distributor"].count()
ax[1][1].set_title("Most popular distributors")
ax[1][1].hist(ranks.values(), bins=len(distributors))

# Some stats
print("The most expensive")
for film in df.nlargest(5, ["budget"]).iloc[:].values:
    print(film[1], film[6])
print("\nHighest box office")
for film in df.nlargest(5, ["box_office"]).iloc[:].values:
    print(film[1], film[6])
# Out:
# The most expensive
# Star Wars: The Force Awakens 447000000.0
# Avengers: Endgame 356000000.0
# Avatar: The Way of Water 350000000.0
# Avengers: Infinity War 325000000.0
# Pirates of the Caribbean: At World's End 300000000.0
#
# Highest box office
# Avatar 237000000.0
# Avengers: Endgame 356000000.0
# Avatar: The Way of Water 350000000.0
# Titanic 200000000.0
# Star Wars: The Force Awakens 447000000.0

# %% [markdown]
# Now everything is correct.

# %%
df.to_csv('output/high_grossing_films.csv', index=False)

# %% [markdown]
# ## Database
#
# Now lets push all our data to database. We will use **Docker** to setup container with **Postgres DB**.

# %% [markdown]
# docker run --name dwv_pg -p 5432:5432 -e POSTGRES_USER=<user_here> -e POSTGRES_PASSWORD=<password_here> -e POSTGRES_DB=<db_name> -d postgres

# %% [markdown]
# Now we have our database up. For connection we will use **PsycoPG2** library. Note that all database credentials must be stored in .env file:

# %% [raw]
# .env
#     DB_NAME=<db_name>
#     DB_USER=<user_here>
#     DB_PASSWORD=<password_here>
#     DB_HOST=localhost
#     DB_PORT=5432

# %%
load_dotenv()

db_params = {
    "dbname": os.getenv("DB_NAME"),
    "user": os.getenv("DB_USER"),
    "password": os.getenv("DB_PASSWORD"),
    "host": os.getenv("DB_HOST"),
    "port": os.getenv("DB_PORT"),
}
db_params
# Out:
# {'dbname': 'dwv_db',
#  'user': 'liqc',
#  'password': 'liqcpwd',
#  'host': 'localhost',
#  'port': '5432'}

# %% [markdown]
# Now with establisched connection, we can define or database

# %%
# Connect to PostgreSQL and insert data
with psycopg2.connect(**db_params) as conn:
    with conn.cursor() as cur:
        cur.execute( """
            DROP TABLE IF EXISTS movies;
            CREATE TABLE IF NOT EXISTS movies (
            id SERIAL PRIMARY KEY,
            year INT CHECK (year >= 1800 AND year <= 2100),
            title VARCHAR(255) NOT NULL,
            director VARCHAR(255),
            distributor VARCHAR(255),
            country VARCHAR(100),
            running_time INT CHECK (running_time > 0),
            budget BIGINT CHECK (budget >= 0),
            box_office BIGINT CHECK (box_office >= 0),
            url TEXT
        );
        """)
        conn.commit()
        print("Data inserted successfully!")
# Out:
# Data inserted successfully!

# %% [markdown]
# Now insert all data in our database

# %%
df = pd.read_csv('output/high_grossing_films.csv', encoding='cp1252')

# Connect to PostgreSQL and insert data
with psycopg2.connect(**db_params) as conn:
    with conn.cursor() as cur:
        for _, row in df.iterrows():
            print(row)
            cur.execute("""
                INSERT INTO movies (year, title, director, distributor, country, running_time, budget, box_office, url)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s);
            """, (row["year"], row["title"], row["director"], row["distributor"],
                  row["country"], row["running_time"], row["budget"], row["box_office"], row["url"]))
        conn.commit()
        print("Data inserted successfully!")
# Out:
# year                                                         1915
# title                                       The Birth of a Nation
# director                                           D. W. Griffith
# distributor                                   Epoch Producing Co.
# country                                             United States
# running_time                                                193.0
# budget                                                   100000.0
# box_office                                               50000000
# url             https://en.wikipedia.org/wiki/The_Birth_of_a_N...
# Name: 0, dtype: object
# year                                                        1916
# title                                                Intolerance
# director                                          D. W. Griffith
# distributor                    Triangle Distributing Corporation
# country                                            United States
# running_time                                               210.0
# budget                                                  385907.0
# box_office                                               1750000
# url             https://en.wikipedia.org/wiki/Intolerance_(film)
# Name: 1, dtype: object
# year                                                         1917
# title                                                   Cleopatra
# director                                        J. Gordon Edwards
# distributor                                  Fox Film Corporation
# country                                             United States
# running_time                                                125.0
# budget                                                   250000.0
# box_office                                                1000000
# url             https://en.wikipedia.org/wiki/Cleopatra_(1917_...
# Name: 2, dtype: object
# year                                                         1918
# title                                                      Mickey
# director                              F. Richard JonesJames Young
# distributor     States Rights Independent ExchangesFilm Bookin...
# country                                             United States
# running_time                                                 93.0
# budget                                                   250000.0
# box_office                                               16450000
# url              https://en.wikipedia.org/wiki/Mickey_(1918_film)
# Name: 3, dtype: object
# year                                                         1919
# title                                             The Miracle Man
# director                                      George Loane Tucker
# distributor                                Famous Playersâ€“Lasky
# country                                             United States
# running_time                                                160.0
# budget                                                   120000.0
# box_office                                                1000000
# url             https://en.wikipedia.org/wiki/The_Miracle_Man_...
# Name: 4, dtype: object
# year                                                   1920
# title                                         Way Down East
# director                                     D. W. Griffith
# distributor                                  United Artists
# country                                       United States
# running_time                                          148.0
# budget                                             800000.0
# box_office                                          7500000
# url             https://en.wikipedia.org/wiki/Way_Down_East
# Name: 5, dtype: object
# year                                                         1921
# title                         The Four Horsemen of the Apocalypse
# director                                               Rex Ingram
# distributor                                        Metro Pictures
# country                                             United States
# running_time                                                134.0
# budget                                                   800000.0
# box_office                                                9200000
# url             https://en.wikipedia.org/wiki/The_Four_Horseme...
# Name: 6, dtype: object
# year                                                         1922
# title                             Douglas Fairbanks in Robin Hood
# director                                               Allan Dwan
# distributor                                        United Artists
# country                                             United States
# running_time                                                127.0
# budget                                                   930000.0
# box_office                                                2500000
# url             https://en.wikipedia.org/wiki/Douglas_Fairbank...
# Name: 7, dtype: object
# year                                                       1923
# title                                         The Covered Wagon
# director                                            James Cruze
# distributor                                  Paramount Pictures
# country                                           United States
# running_time                                               98.0
# budget                                                 782000.0
# box_office                                              4000000
# url             https://en.wikipedia.org/wiki/The_Covered_Wagon
# Name: 8, dtype: object
# year                                                         1924
# title                                                The Sea Hawk
# director                                              Frank Lloyd
# distributor                    Associated First National Pictures
# country                                             United States
# running_time                                                123.0
# budget                                                   800000.0
# box_office                                                2000000
# url             https://en.wikipedia.org/wiki/The_Sea_Hawk_(19...
# Name: 9, dtype: object
# year                                                    1925
# title                                         The Big Parade
# director                                          King Vidor
# distributor                              Loew's Incorporated
# country                                        United States
# running_time                                           151.0
# budget                                              382000.0
# box_office                                          18000000
# url             https://en.wikipedia.org/wiki/The_Big_Parade
# Name: 10, dtype: object
# year                                                         1926
# title                                           For Heaven's Sake
# director                                               Sam Taylor
# distributor                                    Paramount Pictures
# country                                             United States
# running_time                                                 60.0
# budget                                                  2000000.0
# box_office                                                2600000
# url             https://en.wikipedia.org/wiki/For_Heaven%27s_S...
# Name: 11, dtype: object
# year                                                       1927
# title                                                     Wings
# director                                     William A. Wellman
# distributor                  Paramount Famous Lasky Corporation
# country                                           United States
# running_time                                              111.0
# budget                                                2000000.0
# box_office                                              3800000
# url             https://en.wikipedia.org/wiki/Wings_(1927_film)
# Name: 12, dtype: object
# year                                                      1928
# title                                         The Singing Fool
# director                                           Lloyd Bacon
# distributor                              Warner Bros. Pictures
# country                                          United States
# running_time                                             102.0
# budget                                                388000.0
# box_office                                             5916000
# url             https://en.wikipedia.org/wiki/The_Singing_Fool
# Name: 13, dtype: object
# year                                                         1929
# title                                         The Broadway Melody
# director                                           Harry Beaumont
# distributor                                   Metro-Goldwyn-Mayer
# country                                             United States
# running_time                                                100.0
# budget                                                   379000.0
# box_office                                                4400000
# url             https://en.wikipedia.org/wiki/The_Broadway_Melody
# Name: 14, dtype: object
# year                                                         1930
# title                              All Quiet on the Western Front
# director                                          Lewis Milestone
# distributor                                    Universal Pictures
# country                                             United States
# running_time                                                152.0
# budget                                                  1200000.0
# box_office                                                3000000
# url             https://en.wikipedia.org/wiki/All_Quiet_on_the...
# Name: 15, dtype: object
# year                                                         1931
# title                                                Frankenstein
# director                                              James Whale
# distributor                                    Universal Pictures
# country                                             United States
# running_time                                                 70.0
# budget                                                   262007.0
# box_office                                               12000000
# url             https://en.wikipedia.org/wiki/Frankenstein_(19...
# Name: 16, dtype: object
# year                                                         1932
# title                                       The Sign of the Cross
# director                                         Cecil B. DeMille
# distributor                                    Paramount Pictures
# country                                             United States
# running_time                                                125.0
# budget                                                   694065.0
# box_office                                                2738993
# url             https://en.wikipedia.org/wiki/The_Sign_of_the_...
# Name: 17, dtype: object
# year                                                         1933
# title                                                   King Kong
# director                    Merian C. Cooper Ernest B. Schoedsack
# distributor                                    RKO Radio Pictures
# country                                             United States
# running_time                                                100.0
# budget                                                  672254.75
# box_office                                               10001781
# url             https://en.wikipedia.org/wiki/King_Kong_(1933_...
# Name: 18, dtype: object
# year                                                         1934
# title                                             The Merry Widow
# director                                           Ernst Lubitsch
# distributor                                           Loew's Inc.
# country                                             United States
# running_time                                                 99.0
# budget                                                  1605000.0
# box_office                                                2800000
# url             https://en.wikipedia.org/wiki/The_Merry_Widow_...
# Name: 19, dtype: object
# year                                                         1935
# title                                        Mutiny on the Bounty
# director                                              Frank Lloyd
# distributor                                   Metro-Goldwyn-Mayer
# country                                             United States
# running_time                                                132.0
# budget                                                  1950000.0
# box_office                                                4460000
# url             https://en.wikipedia.org/wiki/Mutiny_on_the_Bo...
# Name: 20, dtype: object
# year                                                         1936
# title                                               San Francisco
# director                                           W. S. Van Dyke
# distributor                                           Loew's Inc.
# country                                             United States
# running_time                                                115.0
# budget                                                  1300000.0
# box_office                                                5300000
# url             https://en.wikipedia.org/wiki/San_Francisco_(1...
# Name: 21, dtype: object
# year                                                         1937
# title                             Snow White and the Seven Dwarfs
# director        Supervising DirectorsDavid Hand Sequence Direc...
# distributor                                    RKO Radio Pictures
# country                                             United States
# running_time                                                 83.0
# budget                                                  1500000.0
# box_office                                              418000000
# url             https://en.wikipedia.org/wiki/Snow_White_and_t...
# Name: 22, dtype: object
# year                                                         1938
# title                                  You Can't Take It with You
# director                                              Frank Capra
# distributor                                     Columbia Pictures
# country                                             United States
# running_time                                                126.0
# budget                                                  1644736.0
# box_office                                                2137575
# url             https://en.wikipedia.org/wiki/You_Can%27t_Take...
# Name: 23, dtype: object
# year                                                         1939
# title                                          Gone with the Wind
# director                                           Victor Fleming
# distributor                                           Loew's Inc.
# country                                             United States
# running_time                                                221.0
# budget                                                  3850000.0
# box_office                                              390000000
# url             https://en.wikipedia.org/wiki/Gone_with_the_Wi...
# Name: 24, dtype: object
# year                                                         1940
# title                                                   Pinocchio
# director        Supervising Directors Ben Sharpsteen Hamilton ...
# distributor                                    RKO Radio Pictures
# country                                             United States
# running_time                                                 88.0
# budget                                                  2600000.0
# box_office                                              164000000
# url             https://en.wikipedia.org/wiki/Pinocchio_(1940_...
# Name: 25, dtype: object
# year                                                         1941
# title                                               Sergeant York
# director                                             Howard Hawks
# distributor                                          Warner Bros.
# country                                             United States
# running_time                                                134.0
# budget                                                  1700000.0
# box_office                                                8300000
# url             https://en.wikipedia.org/wiki/Sergeant_York_(f...
# Name: 26, dtype: object
# year                                                         1942
# title                                                       Bambi
# director        Supervising DirectorDavid D. Hand Sequence Dir...
# distributor                                    RKO Radio Pictures
# country                                             United States
# running_time                                                 70.0
# budget                                                   858000.0
# box_office                                              267399999
# url                           https://en.wikipedia.org/wiki/Bambi
# Name: 27, dtype: object
# year                                                         1943
# title                                     For Whom the Bell Tolls
# director                                                 Sam Wood
# distributor                                    Paramount Pictures
# country                                             United States
# running_time                                                170.0
# budget                                                  3000000.0
# box_office                                               17800000
# url             https://en.wikipedia.org/wiki/For_Whom_the_Bel...
# Name: 28, dtype: object
# year                                                  1944
# title                                         Going My Way
# director                                       Leo McCarey
# distributor                             Paramount Pictures
# country                                      United States
# running_time                                         126.0
# budget                                           3000000.0
# box_office                                         6500000
# url             https://en.wikipedia.org/wiki/Going_My_Way
# Name: 29, dtype: object
# year                                                         1945
# title                                                 Mom and Dad
# director                                         William Beaudine
# distributor              Hygienic ProductionsHallmark Productions
# country                                             United States
# running_time                                                 97.0
# budget                                                    67001.0
# box_office                                               40000000
# url             https://en.wikipedia.org/wiki/Mom_and_Dad_(194...
# Name: 30, dtype: object
# year                                                         1946
# title                                           Song of the South
# director        Live action: Harve Foster Animation: Wilfred J...
# distributor                                    RKO Radio Pictures
# country                                             United States
# running_time                                                 94.0
# budget                                                  2125000.0
# box_office                                               65000000
# url               https://en.wikipedia.org/wiki/Song_of_the_South
# Name: 31, dtype: object
# year                                                         1947
# title                                               Forever Amber
# director                Otto PremingerJohn M. Stahl  (uncredited)
# distributor                                      20th Century Fox
# country                                             United States
# running_time                                                138.0
# budget                                                  6400000.0
# box_office                                                5000000
# url             https://en.wikipedia.org/wiki/Forever_Amber_(f...
# Name: 32, dtype: object
# year                                                         1948
# title                                               Easter Parade
# director                                          Charles Walters
# distributor                                          Loew's, Inc.
# country                                             United States
# running_time                                                108.0
# budget                                                  2655000.0
# box_office                                                6800000
# url             https://en.wikipedia.org/wiki/Easter_Parade_(f...
# Name: 33, dtype: object
# year                                                         1949
# title                                          Samson and Delilah
# director                                         Cecil B. DeMille
# distributor                                    Paramount Pictures
# country                                             United States
# running_time                                                134.0
# budget                                                  2900000.0
# box_office                                               25600000
# url             https://en.wikipedia.org/wiki/Samson_and_Delil...
# Name: 34, dtype: object
# year                                                         1950
# title                                                  Cinderella
# director            Wilfred Jackson Hamilton Luske Clyde Geronimi
# distributor                                    RKO Radio Pictures
# country                                             United States
# running_time                                                 76.0
# budget                                                  2200000.0
# box_office                                              182000000
# url             https://en.wikipedia.org/wiki/Cinderella_(1950...
# Name: 35, dtype: object
# year                                                         1951
# title                                                   Quo Vadis
# director                                             Mervyn LeRoy
# distributor                                          Loew's, Inc.
# country                                             United States
# running_time                                                171.0
# budget                                                  7600000.0
# box_office                                               21000000
# url             https://en.wikipedia.org/wiki/Quo_Vadis_(1951_...
# Name: 36, dtype: object
# year                                                         1952
# title                                            This Is Cinerama
# director        Mike ToddMichael Todd, Jr.Walter A. ThompsonFr...
# distributor                        Cinerama Releasing Corporation
# country                                             United States
# running_time                                                115.0
# budget                                                  1000000.0
# box_office                                               41600000
# url                https://en.wikipedia.org/wiki/This_Is_Cinerama
# Name: 37, dtype: object
# year                                                         1953
# title                                                   Peter Pan
# director            Hamilton Luske Clyde Geronimi Wilfred Jackson
# distributor                                    RKO Radio Pictures
# country                                             United States
# running_time                                                 77.0
# budget                                                  4000000.0
# box_office                                               87400000
# url             https://en.wikipedia.org/wiki/Peter_Pan_(1953_...
# Name: 38, dtype: object
# year                                                 1954
# title                                         Rear Window
# director                                 Alfred Hitchcock
# distributor                            Paramount Pictures
# country                                     United States
# running_time                                        111.0
# budget                                          1000000.0
# box_office                                       37900000
# url             https://en.wikipedia.org/wiki/Rear_Window
# Name: 39, dtype: object
# year                                                        1955
# title                                         Lady and the Tramp
# director           Hamilton Luske Clyde Geronimi Wilfred Jackson
# distributor                        Buena Vista Film Distribution
# country                                            United States
# running_time                                                76.0
# budget                                                 4000000.0
# box_office                                             187000000
# url             https://en.wikipedia.org/wiki/Lady_and_the_Tramp
# Name: 40, dtype: object
# year                                                         1956
# title                                        The Ten Commandments
# director                                         Cecil B. DeMille
# distributor                                    Paramount Pictures
# country                                             United States
# running_time                                                220.0
# budget                                                 13000000.0
# box_office                                              122700000
# url             https://en.wikipedia.org/wiki/The_Ten_Commandm...
# Name: 41, dtype: object
# year                                                         1957
# title                                The Bridge on the River Kwai
# director                                               David Lean
# distributor                                     Columbia Pictures
# country                               United KingdomUnited States
# running_time                                                161.0
# budget                                                  2800000.0
# box_office                                               30600000
# url             https://en.wikipedia.org/wiki/The_Bridge_on_th...
# Name: 42, dtype: object
# year                                                         1958
# title                                               South Pacific
# director                                             Joshua Logan
# distributor                                 Magna20th Century-Fox
# country                                             United States
# running_time                                                157.0
# budget                                                  5610000.0
# box_office                                               17500000
# url             https://en.wikipedia.org/wiki/South_Pacific_(1...
# Name: 43, dtype: object
# year                                                         1959
# title                                                     Ben-Hur
# director                                            William Wyler
# distributor                                          Loew's, Inc.
# country                                             United States
# running_time                                                212.0
# budget                                                 15200000.0
# box_office                                              146900000
# url             https://en.wikipedia.org/wiki/Ben-Hur_(1959_film)
# Name: 44, dtype: object
# year                                                         1960
# title                                       Swiss Family Robinson
# director                                              Ken Annakin
# distributor                              Buena Vista Distribution
# country                                             United States
# running_time                                                126.0
# budget                                                  5000000.0
# box_office                                               40000000
# url             https://en.wikipedia.org/wiki/Swiss_Family_Rob...
# Name: 45, dtype: object
# year                                                         1961
# title                              One Hundred and One Dalmatians
# director        Wolfgang Reitherman Hamilton Luske Clyde Geronimi
# distributor                              Buena Vista Distribution
# country                                             United States
# running_time                                                 79.0
# budget                                                  3600000.0
# box_office                                              303000000
# url             https://en.wikipedia.org/wiki/One_Hundred_and_...
# Name: 46, dtype: object
# year                                                         1962
# title                                          Lawrence of Arabia
# director                                               David Lean
# distributor                                     Columbia Pictures
# country                               United KingdomUnited States
# running_time                                                222.0
# budget                                                 15000000.0
# box_office                                               70000000
# url             https://en.wikipedia.org/wiki/Lawrence_of_Arab...
# Name: 47, dtype: object
# year                                                         1963
# title                                                   Cleopatra
# director                                     Joseph L. Mankiewicz
# distributor                                 Twentieth Century-Fox
# country                                             United States
# running_time                                                243.0
# budget                                                 31100000.0
# box_office                                               57800000
# url             https://en.wikipedia.org/wiki/Cleopatra_(1963_...
# Name: 48, dtype: object
# year                                                         1964
# title                                                My Fair Lady
# director                                             George Cukor
# distributor                                          Warner Bros.
# country                                             United States
# running_time                                                173.0
# budget                                                 17000000.0
# box_office                                               72700000
# url             https://en.wikipedia.org/wiki/My_Fair_Lady_(film)
# Name: 49, dtype: object
# year                                                         1965
# title                                          The Sound of Music
# director                                              Robert Wise
# distributor                                      20th Century-Fox
# country                                             United States
# running_time                                                174.0
# budget                                                  8199999.0
# box_office                                              286200000
# url             https://en.wikipedia.org/wiki/The_Sound_of_Mus...
# Name: 50, dtype: object
# year                                                         1966
# title                                 The Bible: In the Beginning
# director                                              John Huston
# distributor                Twentieth Century-Fox Film Corporation
# country                                        ItalyUnited States
# running_time                                                174.0
# budget                                                 15000000.0
# box_office                                               34900000
# url             https://en.wikipedia.org/wiki/The_Bible:_In_th...
# Name: 51, dtype: object
# year                                                         1967
# title                                             The Jungle Book
# director                                      Wolfgang Reitherman
# distributor                              Buena Vista Distribution
# country                                             United States
# running_time                                                 78.0
# budget                                                  4000000.0
# box_office                                              378000000
# url             https://en.wikipedia.org/wiki/The_Jungle_Book_...
# Name: 52, dtype: object
# year                                                         1968
# title                                       2001: A Space Odyssey
# director                                          Stanley Kubrick
# distributor                                   Metro-Goldwyn-Mayer
# country                                            United Kingdom
# running_time                                                139.0
# budget                                                 10500000.0
# box_office                                              146000000
# url             https://en.wikipedia.org/wiki/2001:_A_Space_Od...
# Name: 53, dtype: object
# year                                                         1969
# title                          Butch Cassidy and the Sundance Kid
# director                                          George Roy Hill
# distributor                                      20th Century-Fox
# country                                             United States
# running_time                                                110.0
# budget                                                  6000000.0
# box_office                                              102300000
# url             https://en.wikipedia.org/wiki/Butch_Cassidy_an...
# Name: 54, dtype: object
# year                                                         1970
# title                                                  Love Story
# director                                            Arthur Hiller
# distributor                                    Paramount Pictures
# country                                             United States
# running_time                                                101.0
# budget                                                  2200000.0
# box_office                                              173400000
# url             https://en.wikipedia.org/wiki/Love_Story_(1970...
# Name: 55, dtype: object
# year                                                         1971
# title                                       The French Connection
# director                                         William Friedkin
# distributor                                      20th Century-Fox
# country                                             United States
# running_time                                                104.0
# budget                                                  1800000.0
# box_office                                               75000000
# url             https://en.wikipedia.org/wiki/The_French_Conne...
# Name: 56, dtype: object
# year                                                   1972
# title                                         The Godfather
# director                               Francis Ford Coppola
# distributor                              Paramount Pictures
# country                                       United States
# running_time                                          175.0
# budget                                            6000000.0
# box_office                                        250000000
# url             https://en.wikipedia.org/wiki/The_Godfather
# Name: 57, dtype: object
# year                                                  1973
# title                                         The Exorcist
# director                                  William Friedkin
# distributor                                   Warner Bros.
# country                                      United States
# running_time                                         132.0
# budget                                          12000000.0
# box_office                                       441300000
# url             https://en.wikipedia.org/wiki/The_Exorcist
# Name: 58, dtype: object
# year                                                         1974
# title                                        The Towering Inferno
# director           John Guillermin Irwin Allen (action sequences)
# distributor     20th Century-Fox (United States and Canada) Wa...
# country                                             United States
# running_time                                                165.0
# budget                                                 14000000.0
# box_office                                              203300000
# url             https://en.wikipedia.org/wiki/The_Towering_Inf...
# Name: 59, dtype: object
# year                                                 1975
# title                                                Jaws
# director                                 Steven Spielberg
# distributor                            Universal Pictures
# country                                     United States
# running_time                                        124.0
# budget                                          9000000.0
# box_office                                      476500000
# url             https://en.wikipedia.org/wiki/Jaws_(film)
# Name: 60, dtype: object
# year                                                     1976
# title                                                   Rocky
# director                                     John G. Avildsen
# distributor     United Artists (USA)Star Cinema (Philippines)
# country                                         United States
# running_time                                            119.0
# budget                                              1100000.0
# box_office                                          225000000
# url                       https://en.wikipedia.org/wiki/Rocky
# Name: 61, dtype: object
# year                                                      1977
# title                                                Star Wars
# director                                          George Lucas
# distributor                              Twentieth Century-Fox
# country                                          United States
# running_time                                             121.0
# budget                                              11000000.0
# box_office                                           775400000
# url             https://en.wikipedia.org/wiki/Star_Wars_(film)
# Name: 62, dtype: object
# year                                                   1978
# title                                                Grease
# director                                     Randal Kleiser
# distributor                              Paramount Pictures
# country                                       United States
# running_time                                          110.0
# budget                                            6000000.0
# box_office                                        396300000
# url             https://en.wikipedia.org/wiki/Grease_(film)
# Name: 63, dtype: object
# year                                                      1979
# title                                                Moonraker
# director                                         Lewis Gilbert
# distributor                                     United Artists
# country                      United KingdomUnited StatesFrance
# running_time                                             126.0
# budget                                              34000000.0
# box_office                                           210300000
# url             https://en.wikipedia.org/wiki/Moonraker_(film)
# Name: 64, dtype: object
# year                                                         1980
# title                                     The Empire Strikes Back
# director                                           Irvin Kershner
# distributor                                      20th Century-Fox
# country                                             United States
# running_time                                                124.0
# budget                                                 30500000.0
# box_office                                              538000000
# url             https://en.wikipedia.org/wiki/The_Empire_Strik...
# Name: 65, dtype: object
# year                                                         1981
# title                                     Raiders of the Lost Ark
# director                                         Steven Spielberg
# distributor                                    Paramount Pictures
# country                                             United States
# running_time                                                115.0
# budget                                                 20000000.0
# box_office                                              389900000
# url             https://en.wikipedia.org/wiki/Raiders_of_the_L...
# Name: 66, dtype: object
# year                                                         1982
# title                                  E.T. the Extra-Terrestrial
# director                                         Steven Spielberg
# distributor                                    Universal Pictures
# country                                             United States
# running_time                                                114.0
# budget                                                 10500000.0
# box_office                                              797300000
# url             https://en.wikipedia.org/wiki/E.T._the_Extra-T...
# Name: 67, dtype: object
# year                                                        1983
# title                                         Return of the Jedi
# director                                        Richard Marquand
# distributor                                     20th Century-Fox
# country                                            United States
# running_time                                               132.0
# budget                                                32500000.0
# box_office                                             482000000
# url             https://en.wikipedia.org/wiki/Return_of_the_Jedi
# Name: 68, dtype: object
# year                                                  1984
# title                                         Ghostbusters
# director                                      Ivan Reitman
# distributor                              Columbia Pictures
# country                                      United States
# running_time                                         105.0
# budget                                          25000000.0
# box_office                                       370000000
# url             https://en.wikipedia.org/wiki/Ghostbusters
# Name: 69, dtype: object
# year                                                        1985
# title                                         Back to the Future
# director                                         Robert Zemeckis
# distributor                                   Universal Pictures
# country                                            United States
# running_time                                               116.0
# budget                                                19000000.0
# box_office                                             388800000
# url             https://en.wikipedia.org/wiki/Back_to_the_Future
# Name: 70, dtype: object
# year                                             1986
# title                                         Top Gun
# director                                   Tony Scott
# distributor                        Paramount Pictures
# country                                 United States
# running_time                                    109.0
# budget                                     15000000.0
# box_office                                  357300000
# url             https://en.wikipedia.org/wiki/Top_Gun
# Name: 71, dtype: object
# year                                                      1987
# title                                         Fatal Attraction
# director                                           Adrian Lyne
# distributor                                 Paramount Pictures
# country                                          United States
# running_time                                             119.0
# budget                                              14000000.0
# box_office                                           320100000
# url             https://en.wikipedia.org/wiki/Fatal_Attraction
# Name: 72, dtype: object
# year                                              1988
# title                                         Rain Man
# director                                Barry Levinson
# distributor                  MGM/UA Communications Co.
# country                                  United States
# running_time                                     134.0
# budget                                      25000000.0
# box_office                                   354800000
# url             https://en.wikipedia.org/wiki/Rain_Man
# Name: 73, dtype: object
# year                                                         1989
# title                          Indiana Jones and the Last Crusade
# director                                         Steven Spielberg
# distributor                                    Paramount Pictures
# country                                             United States
# running_time                                                128.0
# budget                                                 48000000.0
# box_office                                              474200000
# url             https://en.wikipedia.org/wiki/Indiana_Jones_an...
# Name: 74, dtype: object
# year                                                       1990
# title                                                     Ghost
# director                                           Jerry Zucker
# distributor                                  Paramount Pictures
# country                                           United States
# running_time                                              127.0
# budget                                               22000000.0
# box_office                                            505700000
# url             https://en.wikipedia.org/wiki/Ghost_(1990_film)
# Name: 75, dtype: object
# year                                                         1991
# title                                  Terminator 2: Judgment Day
# director                                            James Cameron
# distributor                                     Tri-Star Pictures
# country                                             United States
# running_time                                                137.0
# budget                                                 94000000.0
# box_office                                              519000000
# url             https://en.wikipedia.org/wiki/Terminator_2:_Ju...
# Name: 76, dtype: object
# year                                                         1992
# title                                                     Aladdin
# director                                 John Musker Ron Clements
# distributor                     Buena Vista Pictures Distribution
# country                                             United States
# running_time                                                 90.0
# budget                                                 28000000.0
# box_office                                              504100000
# url             https://en.wikipedia.org/wiki/Aladdin_(1992_Di...
# Name: 77, dtype: object
# year                                                         1993
# title                                               Jurassic Park
# director                                         Steven Spielberg
# distributor                                    Universal Pictures
# country                                             United States
# running_time                                                127.0
# budget                                                 63000000.0
# box_office                                             1058000000
# url             https://en.wikipedia.org/wiki/Jurassic_Park_(f...
# Name: 78, dtype: object
# year                                                   1994
# title                                         The Lion King
# ...
# url             https://en.wikipedia.org/wiki/Armageddon_(1998...
# Name: 83, dtype: object
# year                                                         1999
# title                 Star Wars: Episode I â€“ The Phantom Menace
# director                                             George Lucas
# distributor                                      20th Century Fox
# country                                             United States
# running_time                                                134.0
# budget                                                115000000.0
# box_office                                             1046999999
# url             https://en.wikipedia.org/wiki/Star_Wars:_Episo...
# Name: 84, dtype: object
# year                                                         2000
# title                                       Mission: Impossible 2
# director                                                 John Woo
# distributor                                    Paramount Pictures
# country                                             United States
# running_time                                                124.0
# budget                                                120000000.0
# box_office                                              546300000
# url             https://en.wikipedia.org/wiki/Mission:_Impossi...
# Name: 85, dtype: object
# year                                                         2001
# title                    Harry Potter and the Philosopher's Stone
# director                                           Chris Columbus
# distributor                                 Warner Bros. Pictures
# country                                            United Kingdom
# running_time                                                152.0
# budget                                                125000000.0
# box_office                                             1026000000
# url             https://en.wikipedia.org/wiki/Harry_Potter_and...
# Name: 86, dtype: object
# year                                                         2002
# title                       The Lord of the Rings: The Two Towers
# director                                            Peter Jackson
# distributor                                       New Line Cinema
# country                                               New Zealand
# running_time                                                179.0
# budget                                                 94000000.0
# box_office                                              951600000
# url             https://en.wikipedia.org/wiki/The_Lord_of_the_...
# Name: 87, dtype: object
# year                                                         2003
# title               The Lord of the Rings: The Return of the King
# director                                            Peter Jackson
# distributor                                       New Line Cinema
# country                                               New Zealand
# running_time                                                201.0
# budget                                                 94000000.0
# box_office                                             1151000000
# url             https://en.wikipedia.org/wiki/The_Lord_of_the_...
# Name: 88, dtype: object
# year                                                         2004
# title                                                     Shrek 2
# director                Andrew Adamson Kelly Asbury Conrad Vernon
# distributor     DreamWorks Pictures (through DreamWorks Distri...
# country                                             United States
# running_time                                                 92.0
# budget                                                150000000.0
# box_office                                              935500000
# url                         https://en.wikipedia.org/wiki/Shrek_2
# Name: 89, dtype: object
# year                                                         2005
# title                         Harry Potter and the Goblet of Fire
# director                                              Mike Newell
# distributor                                 Warner Bros. Pictures
# country                                            United Kingdom
# running_time                                                157.0
# budget                                                150000000.0
# box_office                                              897500000
# url             https://en.wikipedia.org/wiki/Harry_Potter_and...
# Name: 90, dtype: object
# year                                                         2006
# title                  Pirates of the Caribbean: Dead Man's Chest
# director                                           Gore Verbinski
# distributor                     Buena Vista Pictures Distribution
# country                                             United States
# running_time                                                151.0
# budget                                                225000000.0
# box_office                                             1066000000
# url             https://en.wikipedia.org/wiki/Pirates_of_the_C...
# Name: 91, dtype: object
# year                                                         2007
# title                    Pirates of the Caribbean: At World's End
# director                                           Gore Verbinski
# distributor                     Buena Vista Pictures Distribution
# country                                             United States
# running_time                                                168.0
# budget                                                300000000.0
# box_office                                              963400000
# url             https://en.wikipedia.org/wiki/Pirates_of_the_C...
# Name: 92, dtype: object
# year                                                     2008
# title                                         The Dark Knight
# director                                    Christopher Nolan
# distributor                             Warner Bros. Pictures
# country                                         United States
# running_time                                            152.0
# budget                                            185000000.0
# box_office                                         1006000000
# url             https://en.wikipedia.org/wiki/The_Dark_Knight
# Name: 93, dtype: object
# year                                                        2009
# title                                                     Avatar
# director                                           James Cameron
# distributor                                     20th Century Fox
# country                                           United Kingdom
# running_time                                               162.0
# budget                                               237000000.0
# box_office                                            2923000000
# url             https://en.wikipedia.org/wiki/Avatar_(2009_film)
# Name: 94, dtype: object
# year                                                 2010
# title                                         Toy Story 3
# director                                      Lee Unkrich
# distributor            Walt Disney StudiosMotion Pictures
# country                                     United States
# running_time                                        103.0
# budget                                        200000000.0
# box_office                                     1067000000
# url             https://en.wikipedia.org/wiki/Toy_Story_3
# Name: 95, dtype: object
# year                                                         2011
# title             Harry Potter and the Deathly Hallows â€“ Part 2
# director                                              David Yates
# distributor                                 Warner Bros. Pictures
# country                                            United Kingdom
# running_time                                                130.0
# budget                                                250000000.0
# box_office                                             1342000000
# url             https://en.wikipedia.org/wiki/Harry_Potter_and...
# Name: 96, dtype: object
# year                                                         2012
# title                                                The Avengers
# director                                              Joss Whedon
# distributor                    Walt Disney StudiosMotion Pictures
# country                                             United States
# running_time                                                143.0
# budget                                                220000000.0
# box_office                                             1521000000
# url             https://en.wikipedia.org/wiki/The_Avengers_(20...
# Name: 97, dtype: object
# year                                                        2013
# title                                                     Frozen
# director                                 Chris Buck Jennifer Lee
# distributor                   Walt Disney StudiosMotion Pictures
# country                                            United States
# running_time                                               102.0
# budget                                               150000000.0
# box_office                                            1280000000
# url             https://en.wikipedia.org/wiki/Frozen_(2013_film)
# Name: 98, dtype: object
# year                                                         2014
# title                             Transformers: Age of Extinction
# director                                              Michael Bay
# distributor                                    Paramount Pictures
# country                                             United States
# running_time                                                165.0
# budget                                                210000000.0
# box_office                                             1104000000
# url             https://en.wikipedia.org/wiki/Transformers:_Ag...
# Name: 99, dtype: object
# year                                                         2015
# title                                Star Wars: The Force Awakens
# director                                             J. J. Abrams
# distributor                    Walt Disney StudiosMotion Pictures
# country                                             United States
# running_time                                                138.0
# budget                                                447000000.0
# box_office                                             2069999999
# url             https://en.wikipedia.org/wiki/Star_Wars:_The_F...
# Name: 100, dtype: object
# year                                                         2016
# title                                  Captain America: Civil War
# director                                   Anthony RussoJoe Russo
# distributor                    Walt Disney StudiosMotion Pictures
# country                                             United States
# running_time                                                147.0
# budget                                                250000000.0
# box_office                                             1155000000
# url             https://en.wikipedia.org/wiki/Captain_America:...
# Name: 101, dtype: object
# year                                                         2017
# title                                    Star Wars: The Last Jedi
# director                                             Rian Johnson
# distributor                    Walt Disney StudiosMotion Pictures
# country                                             United States
# running_time                                                152.0
# budget                                                300000000.0
# box_office                                             1334000000
# url             https://en.wikipedia.org/wiki/Star_Wars:_The_L...
# Name: 102, dtype: object
# year                                                         2018
# title                                      Avengers: Infinity War
# director                                   Anthony RussoJoe Russo
# distributor                    Walt Disney StudiosMotion Pictures
# country                                             United States
# running_time                                                149.0
# budget                                                325000000.0
# box_office                                             2052000000
# url             https://en.wikipedia.org/wiki/Avengers:_Infini...
# Name: 103, dtype: object
# year                                                       2019
# title                                         Avengers: Endgame
# director                                 Anthony RussoJoe Russo
# distributor                  Walt Disney StudiosMotion Pictures
# country                                           United States
# running_time                                              181.0
# budget                                              356000000.0
# box_office                                           2799000000
# url             https://en.wikipedia.org/wiki/Avengers:_Endgame
# Name: 104, dtype: object
# year                                                         2020
# title                                   Demon Slayer: Mugen Train
# director                                           Haruo Sotozaki
# distributor                                         Aniplex  Toho
# country                                                     Japan
# running_time                                                119.0
# budget                                                 15700000.0
# box_office                                              507100000
# url             https://en.wikipedia.org/wiki/Demon_Slayer:_Mu...
# Name: 105, dtype: object
# year                                                         2021
# title                                     Spider-Man: No Way Home
# director                                                Jon Watts
# distributor                               Sony Pictures Releasing
# country                                             United States
# running_time                                                148.0
# budget                                                200000000.0
# box_office                                             1923000000
# url             https://en.wikipedia.org/wiki/Spider-Man:_No_W...
# Name: 106, dtype: object
# year                                                         2022
# title                                    Avatar: The Way of Water
# director                                            James Cameron
# distributor                                  20th Century Studios
# country                                             United States
# running_time                                                192.0
# budget                                                350000000.0
# box_office                                             2320000000
# url             https://en.wikipedia.org/wiki/Avatar:_The_Way_...
# Name: 107, dtype: object
# year                                                   2023
# title                                                Barbie
# director                                       Greta Gerwig
# distributor                           Warner Bros. Pictures
# country                                       United States
# running_time                                          114.0
# budget                                          128000000.0
# box_office                                       1446000000
# url             https://en.wikipedia.org/wiki/Barbie_(film)
# Name: 108, dtype: object
# year                                                  2024
# title                                         Inside Out 2
# director                                       Kelsey Mann
# distributor             Walt Disney StudiosMotion Pictures
# country                                      United States
# running_time                                          96.0
# budget                                         200000000.0
# box_office                                      1699000000
# url             https://en.wikipedia.org/wiki/Inside_Out_2
# Name: 109, dtype: object
# Data inserted successfully!

# %% [markdown]
# ## For GitHub Pages
#
# Since GitHub Pages cannot work with databases, all data must be stored in .json file

# %%
def csv_to_json(csv_file, json_file):
    data = []
    
    with open(csv_file, mode='r', encoding='utf-8') as file:
        csv_reader = csv.DictReader(file)
        for row in csv_reader:
            data.append(row)
    
    with open(json_file, mode='w', encoding='utf-8') as file:
        json.dump(data, file, indent=4)
    
    print(f"CSV file '{csv_file}' successfully converted to JSON file '{json_file}'")

# Example usage
csv_to_json('output/high_grossing_films.csv', 'output/data.json')
# Out:
# CSV file 'output/high_grossing_films.csv' successfully converted to JSON file 'output/data.json'
